# %% [markdown]
# ## This handles post experimental data processing for the pilot experiment

# %%
# First import the necessary libraries
import sys
import numpy as np
import matplotlib.pyplot as plt
import os
sys.path.insert(0,'/Users/ashwin/Documents/Y4 project Brain Human Interfaces/General 4th year Github repo/BrainMachineInterfaces')

from Experiment_pointer.experimentFunctions import *

path = "/Users/ashwin/Documents/Y4 project Brain Human Interfaces/General 4th year Github repo/BrainMachineInterfaces/Experiment_pointer/DataAnalysis"
os.chdir(path)
assert os.getcwd() == path

# %% [markdown]
# First we start with some open loop analysis

# %%
# Set the save game location
# Must have format of "../PointerExperimentData/Name_dd_mm__hh_mm_metadata" with no file extension

# saveFile = "../PointerExperimentData/Thanh"
# saveGameLocation = saveFile + "/Thanh_26_01__10_23"
from Experiment_pointer.runFullExperiment import saveDirectory, saveGameLocation
# saveFile = "../PointerExperimentData/Ashwin_13_02"
# saveGameLocation = saveFile + "/Ash_13_02_13_19" # must have format of "Name_dd_mm__hh_mm_metadata" with no file extension


saveFile = saveDirectory

# Replace Experiment pointer with .. as notebook runs from another directory
saveFile = saveFile.replace("Experiment_pointer","..")
saveGameLocation = saveGameLocation.replace("Experiment_pointer","..")
# Create the working directory
working_directory_path = os.path.join(os.getcwd(), saveFile)
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# First extract the r2 value for each decoder

# %%
"""
Train decoders
"""
print(os.getcwd())

# E : Linear : 0.01: no ignore
modelE_dict = fitModelToData(mode = 'RigidBodiesSetE',tester = 'linear', \
compPca = None,savePath=saveGameLocation, colorMap=colorMap,plot=False,DOFOffset= 0.01,ignoreTargetMotionTimesLessThan=0)
decoderEColor = (245,5,5) # (RGB) or F50505 (Hex)
decoderEColorPlt = (245/255,5/255,5/255) # (RGB) or F50505 (Hex)
decoderEColorbar = 'rgb(245,5,5)'
# Save model 
np.savez(saveGameLocation + '_linearRigidBodyEModel.npz', modelCoeff = modelE_dict['Coeff'],modelIntercept = modelE_dict['Intercept'],minDOF = modelE_dict['MinDOF'],
        maxDOF = modelE_dict['MaxDOF'], DOFOffset = modelE_dict['DOFOffset'], predCursorPos = modelE_dict['PredCursorPos'])

# # F : Linear : 0.01 :ignore > 600
modelF_dict = fitModelToData(mode = 'RigidBodiesSetF',tester = 'linear', \
compPca = None,savePath=saveGameLocation, colorMap=colorMap,plot=False,DOFOffset= 0.01,ignoreTargetMotionTimesLessThan=600)

decoderFColor = (53,5,245) # (RGB) or #3505F5 (Hex)
decoderFColorPlt = (53/255,5/255,245/255) # (RGB) or #3505F5 (Hex)
decoderFColorbar = 'rgb(53,5,245)'
# Save model 
np.savez(saveGameLocation + '_linearRigidBodyFModel.npz', modelCoeff = modelF_dict['Coeff'],modelIntercept = modelF_dict['Intercept'],minDOF = modelF_dict['MinDOF'],
        maxDOF = modelF_dict['MaxDOF'], DOFOffset = modelF_dict['DOFOffset'], predCursorPos = modelF_dict['PredCursorPos'])


# # G : Linear : 0.05 :ignore > 0
modelG_dict = fitModelToData(mode = 'RigidBodiesSetG',tester = 'linear', \
compPca = None, savePath=saveGameLocation,colorMap=colorMap,plot=False,DOFOffset= 0.05,ignoreTargetMotionTimesLessThan=0)


decoderGColor = (2,250,242) # (RGB) or  #02FAF2 (Hex)
decoderGColorPlt = (2/255,250/255,242/255) # (RGB) or  #02FAF2 (Hex)
decoderGColorbar = 'rgb(2,250,242)'
# Save model 
np.savez( saveGameLocation + '_linearRigidBodyGModel.npz', modelCoeff = modelG_dict['Coeff'],modelIntercept = modelG_dict['Intercept'],minDOF = modelG_dict['MinDOF'],
        maxDOF = modelG_dict['MaxDOF'], DOFOffset = modelG_dict['DOFOffset'], predCursorPos = modelG_dict['PredCursorPos'])


# # H : Linear : 0.1 :ignore > 0
modelH_dict = fitModelToData(mode = 'RigidBodiesSetH',tester = 'linear', \
compPca = None, savePath=saveGameLocation,colorMap=colorMap,plot=False,DOFOffset= 0.1,ignoreTargetMotionTimesLessThan=0)


decoderHColor = (245,237,5) # (RGB) or F5ED05 (Hex)
decoderHColorPlt = (245/255,237/255,5/255) # (RGB) or F5ED05 (Hex)
decoderHColorbar = 'rgb(245,237,5)'
# Save model 
np.savez(saveGameLocation + '_linearRigidBodyHModel.npz', modelCoeff = modelH_dict['Coeff'],modelIntercept = modelH_dict['Intercept'],minDOF = modelH_dict['MinDOF'],
        maxDOF = modelH_dict['MaxDOF'], DOFOffset = modelH_dict['DOFOffset'], predCursorPos = modelH_dict['PredCursorPos'])

# # I : Linear : 0.1 :ignore > 0
modelI_dict = fitModelToData(mode = 'RigidBodiesSetI',tester = 'linear', \
compPca = None, savePath=saveGameLocation,colorMap=colorMap,plot=False,DOFOffset= 0.1,ignoreTargetMotionTimesLessThan=0)


decoderIColor = (81,142,55) # (RGB) or F5ED05 (Hex)
decoderIColorPlt = (81/255,142/255,55/255) # (RGB) or F5ED05 (Hex)
decoderIColorbar = 'rgb(81,142,55)'
# Save model 
np.savez(saveGameLocation + '_linearRigidBodyIModel.npz', modelCoeff = modelI_dict['Coeff'],modelIntercept = modelI_dict['Intercept'],minDOF = modelI_dict['MinDOF'],
        maxDOF = modelI_dict['MaxDOF'], DOFOffset = modelI_dict['DOFOffset'], predCursorPos = modelI_dict['PredCursorPos'])


# # J : Linear : 0.1 :ignore > 0
modelJ_dict = fitModelToData(mode = 'RigidBodiesSetJ',tester = 'linear', \
compPca = None, savePath=saveGameLocation,colorMap=colorMap,plot=False,DOFOffset= 0.1,ignoreTargetMotionTimesLessThan=0)


decoderJColor = (255,20,242) # (RGB) or F5ED05 (Hex)
decoderJColorPlt = (255/255,20/255,242/255) # (RGB) or F5ED05 (Hex)
decoderJColorbar = 'rgb(255,20,242)'
# Save model 
np.savez(saveGameLocation + '_linearRigidBodyJModel.npz', modelCoeff = modelJ_dict['Coeff'],modelIntercept = modelJ_dict['Intercept'],minDOF = modelJ_dict['MinDOF'],
        maxDOF = modelJ_dict['MaxDOF'], DOFOffset = modelJ_dict['DOFOffset'], predCursorPos = modelJ_dict['PredCursorPos'])
# Out:
# /Users/ashwin/Documents/Y4 project Brain Human Interfaces/General 4th year Github repo/BrainMachineInterfaces/Experiment_pointer/DataAnalysis
# Score: 0.9408348002620075
# /Users/ashwin/Documents/Y4 project Brain Human Interfaces/General 4th year Github repo/BrainMachineInterfaces/Experiment_pointer/experimentFunctions.py:320: RuntimeWarning: divide by zero encountered in scalar divide
#   alpha = np.abs(np.arctan((y_curr - y_prev)/(x_curr - x_prev)))
# Score: -4.883885302479678
# /Users/ashwin/Documents/Y4 project Brain Human Interfaces/General 4th year Github repo/BrainMachineInterfaces/Experiment_pointer/experimentFunctions.py:320: RuntimeWarning: divide by zero encountered in scalar divide
#   alpha = np.abs(np.arctan((y_curr - y_prev)/(x_curr - x_prev)))
# Score: -0.21447397564996395
# /Users/ashwin/Documents/Y4 project Brain Human Interfaces/General 4th year Github repo/BrainMachineInterfaces/Experiment_pointer/experimentFunctions.py:320: RuntimeWarning: divide by zero encountered in scalar divide
#   alpha = np.abs(np.arctan((y_curr - y_prev)/(x_curr - x_prev)))
# Score: 0.9537944895671313
# /Users/ashwin/Documents/Y4 project Brain Human Interfaces/General 4th year Github repo/BrainMachineInterfaces/Experiment_pointer/experimentFunctions.py:320: RuntimeWarning: divide by zero encountered in scalar divide
#   alpha = np.abs(np.arctan((y_curr - y_prev)/(x_curr - x_prev)))
# Score: -0.20623088952986884
# /Users/ashwin/Documents/Y4 project Brain Human Interfaces/General 4th year Github repo/BrainMachineInterfaces/Experiment_pointer/experimentFunctions.py:320: RuntimeWarning: divide by zero encountered in scalar divide
#   alpha = np.abs(np.arctan((y_curr - y_prev)/(x_curr - x_prev)))
# Score: -0.48499534140443235
# /Users/ashwin/Documents/Y4 project Brain Human Interfaces/General 4th year Github repo/BrainMachineInterfaces/Experiment_pointer/experimentFunctions.py:320: RuntimeWarning: divide by zero encountered in scalar divide
#   alpha = np.abs(np.arctan((y_curr - y_prev)/(x_curr - x_prev)))

# %%
# Plot the result
x = np.array([0,1,2,3,4,5])
y = np.array([modelE_dict['Score'],modelF_dict['Score'],modelG_dict['Score'],modelH_dict['Score'],modelI_dict['Score'],modelJ_dict['Score']])
xTicks = ['E','F','G','H','I','J']
plt.xticks(x, xTicks)
plt.title("R squared values for each model")
#plt.ylim(,top = 1)
plt.scatter(x,y)

# %%
# Now plot trajectories using decoder and groundtruth trajectories
decoderFColorbar
# Out:
# 'rgb(53,5,245)'

# %%
# Fetch decoder data
from sklearn.metrics import r2_score
def plotTrajectories(decoder,k,decoderType = None):
    """This function takes in a decoder dict object which is outputted from the fitModelToData function
    It then generates plots of the actual test trajectories (ground truth) against test trajectories predicted
    from the model.

    It also returns an adjusted r2 score, where in each trajectory, the difference between the predicted trajectory
    and actual trajectory start point has been subtracted from the predicted trajectory. This R2 score
    better reflects the model performance decoding a user's movement from a known start position.

    Inputs:
        @param: decoder - A dict object specifying properties of the decoder gathered 
        from the fitModelToData function
        @param k - A int specifying how many trajectories to plot, must be less or equal to the total number of trajectories
        @param decoderType - Char/String specifying decoder type for saved, if none then plots are not saved
    """
    # Extract true and predicted cursor positions for all test data
    Y_pred = np.zeros(decoder['PredCursorPos'].shape)
    correctY = np.zeros(decoder['TestCursorPos'].shape)
    Y_pred_ = decoder['PredCursorPos']
    correctY_ = decoder['TestCursorPos']

    # In pygame y axis is inverted so this is accounted for by mapping normalised y pos from 0 - 1 to 1 - 0
    correctY[:,1] = 1  - correctY_[:,1] 
    Y_pred[:,1] = 1 - Y_pred_[:,1] 
    correctY[:,0] = correctY_[:,0]
    Y_pred[:,0] = Y_pred_[:,0]

    actualPos = []
    predPos = []
    # Retrieve test go cue data

    rigidBodies1, cursorPos1,cursorVel1,goCues1,targetHits1,timeStamps1, minDof1,maxDof1,c = processTrialData(saveGameLocation + "_test",decoder['DOFOffset'])# make this test 
    plt.figure(figsize=(8,6))
    print("Plotting trajectories without compensating for offset")

    # Gather each trajectory
    for i in range(0,len(goCues1)-1):
        plotFrom = goCues1[i]
        plotUntil = targetHits1[i]

        # Upload trajectory path to list for future stage
        actualPos.append(correctY[plotFrom:plotUntil])
        predPos.append(Y_pred[plotFrom:plotUntil])

        # plot first k trajectories
        if i < k:
            plt.plot(correctY[plotFrom:plotUntil,0],correctY[plotFrom:plotUntil,1],color = colorMap[i%len(colorMap)])
            plt.plot(Y_pred[plotFrom:plotUntil,0],Y_pred[plotFrom:plotUntil,1], "--",color = colorMap[i%len(colorMap)])
            
            # Plot start and end markers (for i = 0 this in addition gives a label in the legend )
            if i == 0:
                plt.scatter(correctY[plotFrom,0], correctY[plotFrom,1],s=250, marker=".", color = 'g',label = 'Actual cursor start position')
                # plt.scatter(correctY[plotUntil,0], correctY[plotUntil,1], s=100, marker="D", color = 'g')
                plt.scatter(Y_pred[plotFrom,0], Y_pred[plotFrom,1],s=250, marker=".", color = 'r',label = 'Estimated cursor start position')
                # plt.scatter(Y_pred[plotUntil,0], Y_pred[plotUntil,1], s=60, marker="D", color = 'r')
            else:
                plt.scatter(correctY[plotFrom,0], correctY[plotFrom,1],s=250, marker=".", color = 'g')
                # plt.scatter(correctY[plotUntil,0], correctY[plotUntil,1], s=100, marker="D", color = 'g')
                plt.scatter(Y_pred[plotFrom,0], Y_pred[plotFrom,1],s=250, marker=".", color = 'r')
                # plt.scatter(Y_pred[plotUntil,0], Y_pred[plotUntil,1], s=60, marker="D", color = 'r')

    ax1 = plt.gca()  # Get current axes


    # Remove top and right spines for the first plot
    ax1.spines['top'].set_visible(False)
    ax1.spines['right'].set_visible(False)

    # Set plotting configuration
    plt.xlabel('Normalised X Position',fontsize = 25,fontweight='bold')
    plt.ylabel('Normalised Y position', fontsize = 25,fontweight='bold')
    plt.xticks([0,1],fontsize = 15)
    plt.yticks([0,1],fontsize = 15)
    #plt.title('Trajectories showing actual and estimated cursor position for each target aquisition performed in test set. \n Each trajectory is shown in a different colour and position estimates are derived from set (b) of rigid bodies',fontsize = 15)
    plt.legend()

    # Save the file if necessary
    if decoderType is not None:
        plt.savefig(saveGameLocation + "_Decoder {} trajectories_noOffset".format(decoderType))
    plt.show()

    plt.figure(figsize=(8,6))
    print("Plotting trajectories  compensating for offset")
    for i in range(1,len(goCues1)-1,3): # len(goCues1) len(colorMap)
        plotFrom = goCues1[i]
        plotUntil = targetHits1[i]
        # if np.sqrt(np.square(correctY[plotUntil,0] - correctY[plotFrom,0]) + np.square(correctY[plotUntil,1] - correctY[plotFrom,1])) < 0.15:
        #     break

        offset = Y_pred[plotFrom] - correctY[plotFrom]
        Y_pred[plotFrom:plotUntil] = Y_pred[plotFrom:plotUntil] - offset
        if i == 1:
            plt.plot(correctY[plotFrom:plotUntil,0],correctY[plotFrom:plotUntil,1],color = 'k',label = "Ground Truth Trajectory")
            plt.plot(Y_pred[plotFrom:plotUntil,0],Y_pred[plotFrom:plotUntil,1], "--",color = 'k',label="Decoder Predicted Trajectories")
            plt.scatter(correctY[plotFrom,0], correctY[plotFrom,1],s=250, marker=".", color = 'b',label = 'Cursor Start Position')
        elif i < k:
            plt.plot(correctY[plotFrom:plotUntil,0],correctY[plotFrom:plotUntil,1],color = colorMap[(i-1)%len(colorMap)])
            plt.plot(Y_pred[plotFrom:plotUntil,0],Y_pred[plotFrom:plotUntil,1], "--",color = colorMap[(i-1)%len(colorMap)])
            #if i == 0:
                #plt.scatter(correctY[plotFrom,0], correctY[plotFrom,1],s=250, marker=".", color = 'b',label = 'Cursor start position')
                # plt.scatter(correctY[plotUntil,0], correctY[plotUntil,1], s=100, marker="D", color = 'g')
                #plt.scatter(Y_pred[plotFrom,0], Y_pred[plotFrom,1],s=250, marker=".", color = 'r',label = 'Estimated cursor start position')
                # plt.scatter(Y_pred[plotUntil,0], Y_pred[plotUntil,1], s=60, marker="D", color = 'r')
            #else:
            plt.scatter(correctY[plotFrom,0], correctY[plotFrom,1],s=250, marker=".", color = 'b')
            # plt.scatter(correctY[plotUntil,0], correctY[plotUntil,1], s=100, marker="D", color = 'g')
            #plt.scatter(Y_pred[plotFrom,0], Y_pred[plotFrom,1],s=250, marker=".", color = 'r')
            # plt.scatter(Y_pred[plotUntil,0], Y_pred[plotUntil,1], s=60, marker="D", color = 'r')

    plt.xlabel('Normalised X Position',fontsize = 20,fontweight = 'bold')
    plt.ylabel('Normalised Y Position',fontsize = 20, fontweight = 'bold')
    #plt.title('Trajectories showing actual and estimated cursor position for each target aquisition performed in test set. \n Each trajectory is shown in a different colour and position estimates are derived from set (b) of rigid bodies',fontsize = 15)
    plt.legend(loc="upper right",bbox_to_anchor=(1,1.13),fontsize=50,prop={'weight': 'bold', 'size': 15})
    plt.xticks([0,1],fontsize = 15)
    plt.yticks([0,1],fontsize = 15)

    ax1 = plt.gca()  # Get current axes


    # Remove top and right spines for the first plot
    ax1.spines['top'].set_visible(False)
    ax1.spines['right'].set_visible(False)

    # Save the file if necessary
    if decoderType is not None:
        plt.savefig(saveGameLocation + "_Decoder {} trajectories_withOffset.svg".format(decoderType))
    plt.show()




    # then subtract mean
    allPredPosX = []
    allPredPosY = []
    allTruePosX = []
    allTruePosY = []
    r2AdjTrajVals = []
    r2TrajVals_ = []
    for idx in range(0,len(actualPos)-1):
        truePosTrajectory = actualPos[idx]
        predPosTrajectory = predPos[idx]
        # plt.plot(truePosTrajectory[:,0],truePosTrajectory[:,1])
        # plt.plot(predPosTrajectory[:,0],predPosTrajectory[:,1])
        # plt.show()
        dist = calcDist(truePosTrajectory[0,:],truePosTrajectory[-1,:])
        #print(dist)
        if dist > 500:
            r2TrajectoryScore = float(r2_score(truePosTrajectory, predPosTrajectory))
            #print(r2TrajectoryScore)
            r2TrajVals_.append(r2TrajectoryScore)
        offset = predPosTrajectory[0] - truePosTrajectory[0]
        predPosTrajectory = predPosTrajectory - offset
        if dist > 500:
            r2TrajectoryScoreAdj = float(r2_score(truePosTrajectory, predPosTrajectory))
            r2AdjTrajVals.append(r2TrajectoryScoreAdj)
        for val in truePosTrajectory:
            allTruePosX.append(val[0])
            allTruePosY.append(val[1])
        for val in predPosTrajectory:
            allPredPosX.append(val[0])
            allPredPosY.append(val[1])

    pos_true = np.zeros((len(allTruePosX),2))
    pos_pred = np.zeros(pos_true.shape)
    pos_true[:,0] = allTruePosX
    pos_true[:,1] = allTruePosY
    pos_pred[:,0] = allPredPosX
    pos_pred[:,1] = allPredPosY
    r2Score = r2_score(pos_true, pos_pred)
    print("R2 val for this decoder: {}".format(r2Score))

    return pos_true, pos_pred, r2Score, r2TrajVals_, r2AdjTrajVals


def calcDist(startPos,endPos):
    ranges = [1100,800]
    return np.sqrt(np.sum([ (ranges[i] * (endPos[i] - startPos[i])) ** 2 for i in range(len(startPos))]))

# %%
truePosDecoderE,predPosDecoderE,r2ValAdjDecoderE,r2TrajsE,r2TrajsAdjE = plotTrajectories(modelE_dict,15,'E')
# now need to get true data
# Out:
# Plotting trajectories without compensating for offset
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:81: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_noOffset".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:81: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_noOffset".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:81: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_noOffset".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:81: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox_inches_restore" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_noOffset".format(decoderType))
# Plotting trajectories  compensating for offset
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:128: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_withOffset.svg".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:128: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_withOffset.svg".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:128: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_withOffset.svg".format(decoderType))
# R2 val for this decoder: 0.9709224214252032

# %%
truePosDecoderF,predPosDecoderF,r2ValAdjDecoderF,r2TrajsF,r2TrajsAdjF = plotTrajectories(modelF_dict,15,'F')
# Out:
# Plotting trajectories without compensating for offset
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:81: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_noOffset".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:81: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_noOffset".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:81: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_noOffset".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:81: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox_inches_restore" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_noOffset".format(decoderType))
# Plotting trajectories  compensating for offset
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:128: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_withOffset.svg".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:128: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_withOffset.svg".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:128: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_withOffset.svg".format(decoderType))
# R2 val for this decoder: 0.22629980945510647

# %%
truePosDecoderG,predPosDecoderG,r2ValAdjDecoderG,r2TrajsG,r2TrajsAdjG = plotTrajectories(modelG_dict,16,'G')
# Out:
# Plotting trajectories without compensating for offset
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:81: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_noOffset".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:81: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_noOffset".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:81: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_noOffset".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:81: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox_inches_restore" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_noOffset".format(decoderType))
# Plotting trajectories  compensating for offset
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:128: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_withOffset.svg".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:128: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_withOffset.svg".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:128: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_withOffset.svg".format(decoderType))
# R2 val for this decoder: -0.18456007233731508

# %%
truePosDecoderH,predPosDecoderH,r2ValAdjDecoderH,r2TrajsH,r2TrajsAdjH = plotTrajectories(modelH_dict,15,'H')
# Out:
# Plotting trajectories without compensating for offset
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:81: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_noOffset".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:81: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_noOffset".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:81: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_noOffset".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:81: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox_inches_restore" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_noOffset".format(decoderType))
# Plotting trajectories  compensating for offset
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:128: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_withOffset.svg".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:128: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_withOffset.svg".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:128: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_withOffset.svg".format(decoderType))
# R2 val for this decoder: 0.9958680561638482

# %%
truePosDecoderI,predPosDecoderI,r2ValAdjDecoderI,r2TrajsI,r2TrajsAdjI = plotTrajectories(modelI_dict,15,'I')
# Out:
# Plotting trajectories without compensating for offset
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:81: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_noOffset".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:81: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_noOffset".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:81: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_noOffset".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:81: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox_inches_restore" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_noOffset".format(decoderType))
# Plotting trajectories  compensating for offset
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:128: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_withOffset.svg".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:128: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_withOffset.svg".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:128: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_withOffset.svg".format(decoderType))
# R2 val for this decoder: -0.21415274477155877

# %%
truePosDecoderJ,predPosDecoderJ,r2ValAdjDecoderJ,r2TrajsJ,r2TrajsAdjJ = plotTrajectories(modelJ_dict,15,'J')
# Out:
# Plotting trajectories without compensating for offset
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:81: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_noOffset".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:81: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_noOffset".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:81: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_noOffset".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:81: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox_inches_restore" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_noOffset".format(decoderType))
# Plotting trajectories  compensating for offset
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:128: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_withOffset.svg".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:128: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_withOffset.svg".format(decoderType))
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/3688513397.py:128: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation + "_Decoder {} trajectories_withOffset.svg".format(decoderType))
# R2 val for this decoder: -0.10855517094627076

# %% [markdown]
# Now find the angular accuracy metric

# %%
magErrorsE = modelE_dict['Mag Errors']  
magErrorsF = modelF_dict['Mag Errors']
magErrorsG = modelG_dict['Mag Errors']
magErrorsH = modelH_dict['Mag Errors']
magErrorsI = modelI_dict['Mag Errors']
magErrorsJ = modelJ_dict['Mag Errors']

angleErrorsE = modelE_dict['Angular Errors']
angleErrorsF = modelF_dict['Angular Errors']
angleErrorsG = modelG_dict['Angular Errors']
angleErrorsH = modelH_dict['Angular Errors']
angleErrorsI = modelI_dict['Angular Errors']
angleErrorsJ = modelJ_dict['Angular Errors']
#fig,ax = plt.subplot(111,polar= True)
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})

ax.scatter(angleErrorsE,magErrorsE,color = decoderEColorPlt,label = "Decoder E")
ax.scatter(angleErrorsF,magErrorsF,color = decoderFColorPlt, label = 'Decoder F')
ax.scatter(angleErrorsG,magErrorsG,color = decoderGColorPlt, label = 'Decoder G')
ax.scatter(angleErrorsH,magErrorsH,color = decoderHColorPlt, label = 'Decoder H')
ax.scatter(angleErrorsI,magErrorsI,color = decoderIColorPlt, label = 'Decoder I')
ax.scatter(angleErrorsJ,magErrorsJ,color = decoderJColorPlt, label = 'Decoder J')
ax.set_rticks([0.02]) 
fig.legend(loc='upper right'
           )  # Move legend outside
#plt.legend()
plt.savefig(saveGameLocation+"_mag_acc_polarplot.svg")
plt.show()
# Out:
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/772882198.py:27: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation+"_mag_acc_polarplot.svg")
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/772882198.py:27: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation+"_mag_acc_polarplot.svg")
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/772882198.py:27: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation+"_mag_acc_polarplot.svg")

# %%
# Plot the result
accE = modelE_dict['Angular Accuracy']
accF = modelF_dict['Angular Accuracy']
accG = modelG_dict['Angular Accuracy']
accH = modelH_dict['Angular Accuracy']
accI = modelI_dict['Angular Accuracy']
accJ = modelJ_dict['Angular Accuracy']

x = np.array([0,1,2,3,4,5])
y = np.array([accE,accF,accG,accH,accI,accJ])
xTicks = ['E','F','G','H','I','J']
plt.xticks(x, xTicks)
#plt.ylim(,top = 1)
plt.scatter(x,y)

# %%
#Plot all metrics on same graph
angularAccuracies =  [accE,accF,accG,accH,accI,accJ]
magE = modelE_dict['Mag Accuracy']
magF = modelF_dict['Mag Accuracy']
magG = modelG_dict['Mag Accuracy']
magH = modelH_dict['Mag Accuracy']
magI = modelI_dict['Mag Accuracy']
magJ = modelJ_dict['Mag Accuracy']

magAccuracies = [magE,magF,magG,magH,magI,magJ]
r2Vals = [modelE_dict['Score'],modelF_dict['Score'],modelG_dict['Score'],modelH_dict['Score'],modelI_dict['Score'],modelJ_dict['Score']]
r2ValsAdj = [r2ValAdjDecoderE,r2ValAdjDecoderF,r2ValAdjDecoderG,r2ValAdjDecoderH,r2ValAdjDecoderI,r2ValAdjDecoderJ]


# x = np.array([0,1,2,3,4,5])
# y = np.array(angularAccuracies)
# xTicks = ['E','F','G','H','I','J']
# plt.xticks(x, xTicks)

decoderColorList = [decoderEColorPlt,decoderFColorPlt,decoderGColorPlt,decoderHColorPlt,decoderIColorPlt,decoderJColorPlt]
# plt.scatter(x,angularAccuracies, label = "Angular Accuracy", color = decoderColorList)
# plt.scatter(x,magAccuracies, label = "Magnitude Accuracy",marker = 'x', color = decoderColorList)
# plt.scatter(x,r2Vals, label = "R2 Value",marker = 'd' ,color = decoderColorList)
# plt.scatter(x,r2ValsAdj, label = "R2 Offset Adjusted Value",marker = 'v' ,color = decoderColorList)
# plt.legend()

# import matplotlib.pyplot as plt
# import numpy as np

# # Sample data
categories = ['E', 'F', 'G','H','I','J']

# %%
# Width of a bar 
width = 2

# Create a 2x2 grid of subplots
fig, axs = plt.subplots(4, 1, figsize=(10, 12))  # Adjust figsize as needed

# Flatten the axs array for easy iteration
axs = axs.flatten()
metrics = [
    angularAccuracies, 
    magAccuracies,
    r2Vals,
    r2ValsAdj
]
categories = [
    "Angular Accuracy",
    "Magnitude Accuracy",
    "R2 Value",
    "R2 Offset Adjusted value "
]
# Iterate through categories and create separate bar plots
for i in range(len(categories)):
    x = np.arange(6)  # Four bars per category
    if i == 0:
        axs[i].bar(x[0] - width, metrics[i][0], width, label= "Decoder E",color = decoderColorList[0])
        axs[i].bar(x[1], metrics[i][1], width, label =  "Decoder F",color = decoderColorList[1])
        axs[i].bar(x[2] + 1* width, metrics[i][2], width, label = "Decoder G",color = decoderColorList[2])
        axs[i].bar(x[3] + 2*width, metrics[i][3], width, label = "Decoder H ",color = decoderColorList[3])
        axs[i].bar(x[4] + 3*width, metrics[i][4], width, label = "Decoder I ",color = decoderColorList[4])
        axs[i].bar(x[5] + 4*width, metrics[i][5], width, label = "Decoder J ",color = decoderColorList[5])
    else:
        axs[i].bar(x[0] - width, metrics[i][0], width,color = decoderColorList[0])
        axs[i].bar(x[1], metrics[i][1], width,color = decoderColorList[1])
        axs[i].bar(x[2] + width, metrics[i][2], width,color = decoderColorList[2])
        axs[i].bar(x[3] + 2*width, metrics[i][3], width,color = decoderColorList[3])
        axs[i].bar(x[4] + 3*width, metrics[i][4], width,color = decoderColorList[4])
        axs[i].bar(x[5] + 4*width, metrics[i][5], width,color = decoderColorList[5])

    # Setting titles and xticks for each subplot
    axs[i].set_title(f'{categories[i]}', fontsize = 15)
    axs[i].set_xticks([-2,1,4,7,10,13])
    axs[i].set_xticklabels(['Decoder E', 'Decoder F', 'Decoder G', 'Decoder H','Decoder I', 'Decoder J'],fontsize = 15)
    axs[i].set_yticks([-1,0,1])
    axs[i].axhline(0, color='black', linewidth=0.8)
    axs[i].tick_params(axis='x', length=0)

    # Remove top, right, and bottom borders, keep left
    axs[i].spines['top'].set_visible(False)
    axs[i].spines['right'].set_visible(False)
    axs[i].spines['bottom'].set_visible(False)
    axs[i].tick_params(axis='x', which='major', pad=-75)  # Move x-tick labels closer to y=0 line

    # Adjust position of the first x-axis label
    if i == 2:  # For the first subplot
        for label in axs[i].get_xticklabels():
            if label.get_text() == 'Decoder C':  # Identify the label by its text
                label.set_y(0.2)  # Adjust the vertical position
            if label.get_text() == 'Decoder B':  # Identify the label by its text
                label.set_y(0.2)  # Adjust the vertical position

#fig.suptitle('Overall Title for All Subplots', fontsize=15)
#fig.legend(loc='upper right', bbox_to_anchor=(1.1, 1.05))  # Move legend outside

# Adjust layout
plt.tight_layout()
fig.subplots_adjust(left = 0.1,top=0.88)  # Adjust the top of the subplots to fit the super title


#fig.text(0.7, 0.07, 'Metric Type', ha='center', va='center',fontsize = 15)
fig.text(0.05, 0.5,'Metric Normalised Value' , ha='center', va='center', rotation='vertical', fontsize = 15)


# Adjust layout
plt.tight_layout()
fig.subplots_adjust(left = 0.15) 
plt.savefig(saveGameLocation+"_accuracies.svg")
# Show the plot
plt.show()
# Out:
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/207897131.py:76: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation+"_accuracies.svg")
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/207897131.py:76: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation+"_accuracies.svg")
# /var/folders/bd/_1l03dkj5l11l_q7br4tgzh40000gn/T/ipykernel_61095/207897131.py:76: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(saveGameLocation+"_accuracies.svg")

# %%
# Functions for color coding schematic

from bs4 import BeautifulSoup
import plotly.graph_objects as go
from svgpathtools import parse_path
import numpy as np

from lib_streamAndRenderDataWorkflows.config_streaming import bodyParts


def extractShapesFromSVG(location,parts):
    """Extracts all shapes from an svg file

    Inputs:
        @param: location: relative location of svg file
        @param: parts: list of names of defined parts that map to shapes (should be in order of values that correspond to color strength
        of each shape) Additionally the list of names must be the same as the list of named polygons on the svg file

    Returns:
        @param: elements: list of lists, each list is the ordered vertices in each polygon, each vertex
        is supplied as an index corresponding to the location of the vertex in points
        @param: points: List of (x,y) of each point
        @param: path_elements - list of raw path data from the svg for all shapes
        @param: partMappings - mapping of each shape to its  part (value is -1 if it is just a line)
        """
    
    # Load the SVG content
    with open(location, 'r') as file:
        svg_content = file.read()

    # Create a BeautifulSoup object and specify the lxml parser
    soup = BeautifulSoup(svg_content, 'html.parser')

    # Find all the path elements
    path_elements = soup.find_all('path')








    # Initialize lists for points and elements
    points = [] # holds all points
    elements = [] # holds each polygon

    # Function to add a point if it's not already in the list and return its index
    def add_point(point):
        if point not in points:
            points.append(point)
        return points.index(point)
    #print(path_elements[0])
    partMappings = []
    # describes which polygon each rigid body is responsible, -1 indicates it is just a line

    # Iterate through each path (polygon) and update points / elements
    for pathRawData in path_elements:
        path_string = str(parse_path(pathRawData))
        truthList = [parts[i] in path_string for i in range(0,len(parts))]
        try:
            partMappings.append( truthList.index(1) )
        except:
            partMappings.append( -1 )
        
        path_data = parse_path(pathRawData.get('d'))
        # Iterate through each line in the path
        element_ =  []
        for i,line in enumerate(path_data):
            # Extract start and end points 
            start_point = (line.start.real, -line.start.imag)
            
            end_point = (line.end.real, -line.end.imag)

            # Get indices of start and end points
            start_index = add_point(start_point)
            if i == 0:
                element_.append(start_index)
            end_index = add_point(end_point)

            # Add element as indices of points
            element_.append(end_index)
        elements.append(element_)

    return elements, points, path_elements,partMappings



def drawObject(points,elements,colors,partMapping,savePath = "Composite image.svg",lineColor = '#000000',lightColor = None, darkColor = None ):
    """
    This function draws the polygons passed in elements to the screen
    requires import plotly.graph_objects as go
    and from bs4 import BeautifulSoup


    Inputs:
        @param points: list of all points (x,y) that polygon vertices form at
        @param elements: List of lists corresponding to list of vertices in each polygon, each vertex entry should be the index of the vertex from the list points 
        @param colors: List of colors for all defined shapes ( not including lines)
        @param partMapping: pointer to map each polygon to each color, if not a defined shape, the value is -1
        @param (optional) savePath: saves composite image color coded map to savePath location
        @param (optional) lineColor: color of any non defined shapes (lines) set as black
    """
    nodes=np.asarray(points).transpose()
    shapeIdx = 0
    polygons= []
    
    # Create a dummy scatter for color bar
    #print(lightColor,darkColor)
    colorbar_trace = go.Scatter(
        x=[None], 
        y=[None], 
        mode='markers',
        
        marker=dict(
            
            colorscale=[(0, lightColor), (1, darkColor)], # Adjust the colorscale based on your color range
            cmin=0,
            cmax=1,
            colorbar=dict(title="",
                        tickvals = []
                       ) # Add your color bar title here

        ),
        hoverinfo='none'
    )
    polygons.append(colorbar_trace)
    for k, element in enumerate(elements):
        if partMapping[k] != -1:
            # Fill shape
            colorIdx = partMapping[k]
            fillcolor = colors[colorIdx]
            shapeIdx += 1
        else:
            # Fill line
            fillcolor = lineColor

        polygons.append(go.Scatter(x=nodes[0][element],y=nodes[1][element],
            mode='lines',line=dict(color=lineColor, width=2), fill='toself',fillcolor=fillcolor))
        
    # Now plot data
        
    axis = dict(showline=False, zeroline=False, showgrid = False,ticks='', showticklabels=False)

    fig = go.Figure(polygons)

    fig.update_layout(width=600, height=900, showlegend=False,xaxis=axis, yaxis=axis,template="none")
    if savePath != None:    
        fig.write_image(savePath)
    fig.show()

def get_color_hex(value, light_color, dark_color):
    """Function returns hexadecimal color based on value between 0 and 1."""
    # Check value is bounded first
    value = max(0, min(1, value))

    # Interpolate between light and dark colors
    r = int(light_color[0] + value * (dark_color[0] - light_color[0]))
    g = int(light_color[1] + value * (dark_color[1] - light_color[1]))
    b = int(light_color[2] + value * (dark_color[2] - light_color[2]))

    # Return as hexadecimal
    return '#{:02x}{:02x}{:02x}'.format(r, g, b)

# %%
# Code for color code Plot for Decoder E

white =  (255, 255, 255) # White
whiteColorBar = 'rgb(255, 255, 255)'
darkColor = 'rgb(245,5,5)'
print("Body Heatmap for decoder E x-axis")
# Retrieve and reshape data 
coefficientsModelE_x = modelE_dict['Coeff'][0]
coefficientsModelE_x_reshaped = coefficientsModelE_x.reshape(18,3)

# Sum all coefficients across all rotations and positions for each rigid body and normalise
coefficientsModelE_sumDOF = np.sum(np.abs(coefficientsModelE_x_reshaped),1)
coefficientsModelE_sumDOF = coefficientsModelE_sumDOF / sum(coefficientsModelE_sumDOF)

# Create a list with all rigid bodies in skeleton and set rigid bodies that don't have components to 0
coefficients_E_X = np.zeros((19))
coefficients_E_X[0:12] = coefficientsModelE_sumDOF[0:12]
coefficients_E_X[13:19] = coefficientsModelE_sumDOF[12:18]

# Normalise so the max value is 1
coefficients_E_X = coefficients_E_X/ max(coefficients_E_X)






# Set location and import body parts ( list of names of bodies that coefficients correspond to)
location = '../../BodyGraphics/body.svg'

# Extract shape data from the svg file
elements,points,pathElements,bodyPartMapping = extractShapesFromSVG(location=location,parts=bodyParts)

# Set colours for each coefficient
colours = [get_color_hex(i,white,decoderEColor) for i in coefficients_E_X]


# Draw the object 
drawObject(points,elements,colours,bodyPartMapping,saveGameLocation+"_bodySchematic_decoderE_xAxis.svg",
           lightColor = whiteColorBar, darkColor = decoderEColorbar)
#print(coefficients_E_X)


# Now for y plane


print("Body Heatmap for decoder E y-axis")
# Retrieve and reshape data 
coefficientsModelE_y = modelE_dict['Coeff'][1]
coefficientsModelE_y_reshaped = coefficientsModelE_y.reshape(18,3)

# Sum all coefficients across all rotations and positions for each rigid body and normalise
coefficientsModelE_sumDOF = np.sum(np.abs(coefficientsModelE_y_reshaped),1)
coefficientsModelE_sumDOF = coefficientsModelE_sumDOF / sum(coefficientsModelE_sumDOF)

# Create a list with all rigid bodies in skeleton and set rigid bodies that don't have components to 0
coefficients_E_Y = np.zeros((19))
coefficients_E_Y[0:12] = coefficientsModelE_sumDOF[0:12]
coefficients_E_Y[13:19] = coefficientsModelE_sumDOF[12:18]

# Normalise so the max value is 1
coefficients_E_Y = coefficients_E_Y/ max(coefficients_E_Y)








# Set location and import body parts ( list of names of bodies that coefficients correspond to)
location = '../../BodyGraphics/body.svg'

# Extract shape data from the svg file
elements,points,pathElements,bodyPartMapping = extractShapesFromSVG(location=location,parts=bodyParts)

# Set colours for each coefficient
colours = [get_color_hex(i,white,decoderEColor) for i in coefficients_E_Y]


# Draw the object 
drawObject(points,elements,colours,bodyPartMapping,saveGameLocation+"_bodySchematic_decoderE_yAxis.svg",
        lightColor = whiteColorBar, darkColor = decoderEColorbar)
#print(coefficients_E_X)
# Out:
# Body Heatmap for decoder E x-axis
# /usr/local/lib/python3.11/site-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# Body Heatmap for decoder E y-axis
# /usr/local/lib/python3.11/site-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning:
#
# It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.

# %%
# Color code Plot for Decoder F
print("Body Heatmap for decoder F x-axis")
# Retrieve and reshape data 
coefficientsModel_x = modelF_dict['Coeff'][0]
coefficientsModel_x_reshaped = coefficientsModel_x.reshape(15,3)

# Sum all coefficients across all rotations and positions for each rigid body and normalise
coefficientsModelSumDOF = np.sum(np.abs(coefficientsModel_x_reshaped),1)
coefficientsModelSumDOF = coefficientsModelSumDOF / sum(coefficientsModelSumDOF)

# Create a list with all rigid bodies in skeleton and set rigid bodies that don't have components to 0
coefficients_X = np.zeros((19))
coefficients_X[0:9] = coefficientsModelSumDOF[0:9]
coefficients_X[13:19] = coefficientsModelSumDOF[9:15]

# Normalise so the max value is 1
coefficients_X = coefficients_X/ max(coefficients_X)




# Set location and import body parts ( list of names of bodies that coefficients correspond to)


# Extract shape data from the svg file
elements,points,pathElements,bodyPartMapping = extractShapesFromSVG(location=location,parts=bodyParts)

# Set colours for each coefficient
colours = [get_color_hex(i,white,decoderFColor) for i in coefficients_X]


# Draw the object 
drawObject(points,elements,colours,bodyPartMapping,saveGameLocation+"_bodySchematic_decoderF_xAxis.svg",
           lightColor=whiteColorBar,darkColor=decoderFColorbar)
#print(coefficients_E_X)


# For y axis
print("Body Heatmap for decoder F y-axis")
# Retrieve and reshape data 
coefficientsModel_y = modelF_dict['Coeff'][1]
coefficientsModel_y_reshaped = coefficientsModel_y.reshape(15,3)

# Sum all coefficients across all rotations and positions for each rigid body and normalise
coefficientsModelSumDOF = np.sum(np.abs(coefficientsModel_y_reshaped),1)
coefficientsModelSumDOF = coefficientsModelSumDOF / sum(coefficientsModelSumDOF)

# Create a list with all rigid bodies in skeleton and set rigid bodies that don't have components to 0
coefficients_Y = np.zeros((19))
coefficients_Y[0:9] = coefficientsModelSumDOF[0:9]
coefficients_Y[13:19] = coefficientsModelSumDOF[9:15]

# Normalise so the max value is 1
coefficients_Y = coefficients_Y/ max(coefficients_Y)


# Set location and import body parts ( list of names of bodies that coefficients correspond to)


# Extract shape data from the svg file
elements,points,pathElements,bodyPartMapping = extractShapesFromSVG(location=location,parts=bodyParts)

# Set colours for each coefficient
colours = [get_color_hex(i,white,decoderFColor) for i in coefficients_Y]


# Draw the object 
drawObject(points,elements,colours,bodyPartMapping,saveGameLocation+"_bodySchematic_decoderF_yAxis.svg",
lightColor=whiteColorBar,darkColor=decoderFColorbar)
#print(coefficients_E_X)
# Out:
# Body Heatmap for decoder F x-axis
# Body Heatmap for decoder F y-axis

# %%
print("Body Heatmap for decoder G x-axis")
# Plot for Decoder G

# Retrieve and reshape data 
coefficientsModel_x = modelG_dict['Coeff'][0]

coefficientsModel_x_reshaped = coefficientsModel_x.reshape(1,3)

# Sum all coefficients across all rotations and positions for each rigid body and normalise
coefficientsModelSumDOF = np.sum(np.abs(coefficientsModel_x_reshaped),1)
coefficientsModelSumDOF = coefficientsModelSumDOF / sum(coefficientsModelSumDOF)


# Create a list with all rigid bodies in skeleton and set rigid bodies that don't have components to 0
coefficients_X = np.zeros((19))
coefficients_X[8] = coefficientsModelSumDOF


# Normalise so the max value is 1
coefficients_X = coefficients_X/ max(coefficients_X)




# Set location and import body parts ( list of names of bodies that coefficients correspond to)


# Extract shape data from the svg file
elements,points,pathElements,bodyPartMapping = extractShapesFromSVG(location=location,parts=bodyParts)

# Set colours for each coefficient

colours = [get_color_hex(i,white,decoderGColor) for i in coefficients_X]

print(colours)
# Draw the object 
drawObject(points,elements,colours,bodyPartMapping,saveGameLocation+"_bodySchematic_decoderG_xAxis.svg",lightColor = whiteColorBar, darkColor = decoderGColorbar)
#print(coefficients_E_X)


print("Body Heatmap for decoder G y-axis")
# Plot for Y axis

# Retrieve and reshape data 
coefficientsModel_y = modelG_dict['Coeff'][1]

coefficientsModel_y_reshaped = coefficientsModel_y.reshape(1,3)

# Sum all coefficients across all rotations and positions for each rigid body and normalise
coefficientsModelSumDOF = np.sum(np.abs(coefficientsModel_y_reshaped),1)
coefficientsModelSumDOF = coefficientsModelSumDOF / sum(coefficientsModelSumDOF)


# Create a list with all rigid bodies in skeleton and set rigid bodies that don't have components to 0
coefficients_Y = np.zeros((19))
coefficients_Y[8] = coefficientsModelSumDOF


# Normalise so the max value is 1
coefficients_Y = coefficients_Y/ max(coefficients_Y)

# Set location and import body parts ( list of names of bodies that coefficients correspond to)


# Extract shape data from the svg file
elements,points,pathElements,bodyPartMapping = extractShapesFromSVG(location=location,parts=bodyParts)

# Set colours for each coefficient

colours = [get_color_hex(i,white,decoderGColor) for i in coefficients_Y]

print(colours)
# Draw the object 
drawObject(points,elements,colours,bodyPartMapping,saveGameLocation+"_bodySchematic_decoderG_yAxis.svg",lightColor = whiteColorBar, darkColor = decoderGColorbar )
#print(coefficients_E_X)
# Out:
# Body Heatmap for decoder G x-axis
# ['#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#02faf2', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff']
# Body Heatmap for decoder G y-axis
# ['#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#02faf2', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff']

# %%
print("Body Heatmap for decoder H x-axis")
# Plot for Decoder H

# Retrieve and reshape data 
coefficientsModel_x = modelH_dict['Coeff'][0]

coefficientsModel_x_reshaped = coefficientsModel_x.reshape(1,3)

# Sum all coefficients across all rotations and positions for each rigid body and normalise
coefficientsModelSumDOF = np.sum(np.abs(coefficientsModel_x_reshaped),1)
coefficientsModelSumDOF = coefficientsModelSumDOF / sum(coefficientsModelSumDOF)


# Create a list with all rigid bodies in skeleton and set rigid bodies that don't have components to 0
coefficients_X = np.zeros((19))
coefficients_X[12] = coefficientsModelSumDOF


# Normalise so the max value is 1
coefficients_X = coefficients_X/ max(coefficients_X)




# Set location and import body parts ( list of names of bodies that coefficients correspond to)


# Extract shape data from the svg file
elements,points,pathElements,bodyPartMapping = extractShapesFromSVG(location=location,parts=bodyParts)

# Set colours for each coefficient

colours = [get_color_hex(i,white,decoderHColor) for i in coefficients_X]

print(colours)
# Draw the object 
drawObject(points,elements,colours,bodyPartMapping,saveGameLocation+"_bodySchematic_decoderH_xAxis.svg",lightColor=whiteColorBar,darkColor = decoderHColorbar)
#print(coefficients_E_X)


print("Body Heatmap for decoder H y-axis")
# Plot for Y axis

# Retrieve and reshape data 
coefficientsModel_y = modelH_dict['Coeff'][1]

coefficientsModel_y_reshaped = coefficientsModel_y.reshape(1,3)

# Sum all coefficients across all rotations and positions for each rigid body and normalise
coefficientsModelSumDOF = np.sum(np.abs(coefficientsModel_y_reshaped),1)
coefficientsModelSumDOF = coefficientsModelSumDOF / sum(coefficientsModelSumDOF)


# Create a list with all rigid bodies in skeleton and set rigid bodies that don't have components to 0
coefficients_Y = np.zeros((19))
coefficients_Y[12] = coefficientsModelSumDOF


# Normalise so the max value is 1
coefficients_Y = coefficients_Y/ max(coefficients_Y)

# Set location and import body parts ( list of names of bodies that coefficients correspond to)


# Extract shape data from the svg file
elements,points,pathElements,bodyPartMapping = extractShapesFromSVG(location=location,parts=bodyParts)

# Set colours for each coefficient

colours = [get_color_hex(i,white,decoderHColor) for i in coefficients_Y]

print(colours)
# Draw the object 
drawObject(points,elements,colours,bodyPartMapping,saveGameLocation+"_bodySchematic_decoderH_yAxis.svg",lightColor=whiteColorBar,darkColor = decoderHColorbar)
#print(coefficients_E_X)
# Out:
# Body Heatmap for decoder H x-axis
# ['#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#f5ed05', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff']
# Body Heatmap for decoder H y-axis
# ['#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#f5ed05', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff', '#ffffff']

# %%
# Color code Plot for Decoder I
print("Body Heatmap for decoder I x-axis")
# Retrieve and reshape data 
coefficientsModel_x = modelI_dict['Coeff'][0]
coefficientsModel_x_reshaped = coefficientsModel_x.reshape(6,3)

# Sum all coefficients across all rotations and positions for each rigid body and normalise
coefficientsModelSumDOF = np.sum(np.abs(coefficientsModel_x_reshaped),1)
coefficientsModelSumDOF = coefficientsModelSumDOF / sum(coefficientsModelSumDOF)

# Create a list with all rigid bodies in skeleton and set rigid bodies that don't have components to 0
coefficients_X = np.zeros((19))

coefficients_X[13:19] = coefficientsModelSumDOF[0:6]

# Normalise so the max value is 1
coefficients_X = coefficients_X/ max(coefficients_X)




# Set location and import body parts ( list of names of bodies that coefficients correspond to)


# Extract shape data from the svg file
elements,points,pathElements,bodyPartMapping = extractShapesFromSVG(location=location,parts=bodyParts)

# Set colours for each coefficient
colours = [get_color_hex(i,white,decoderIColor) for i in coefficients_X]


# Draw the object 
drawObject(points,elements,colours,bodyPartMapping,saveGameLocation+"_bodySchematic_decoderI_xAxis.svg",
           lightColor=whiteColorBar,darkColor=decoderIColorbar)
#print(coefficients_E_X)


# For y axis
print("Body Heatmap for decoder I y-axis")
# Retrieve and reshape data 
coefficientsModel_y = modelI_dict['Coeff'][1]
coefficientsModel_y_reshaped = coefficientsModel_y.reshape(6,3)

# Sum all coefficients across all rotations and positions for each rigid body and normalise
coefficientsModelSumDOF = np.sum(np.abs(coefficientsModel_y_reshaped),1)
coefficientsModelSumDOF = coefficientsModelSumDOF / sum(coefficientsModelSumDOF)

# Create a list with all rigid bodies in skeleton and set rigid bodies that don't have components to 0
coefficients_Y = np.zeros((19))

coefficients_Y[13:19] = coefficientsModelSumDOF[0:6]

# Normalise so the max value is 1
coefficients_Y = coefficients_Y/ max(coefficients_Y)


# Set location and import body parts ( list of names of bodies that coefficients correspond to)


# Extract shape data from the svg file
elements,points,pathElements,bodyPartMapping = extractShapesFromSVG(location=location,parts=bodyParts)

# Set colours for each coefficient
colours = [get_color_hex(i,white,decoderIColor) for i in coefficients_Y]


# Draw the object 
drawObject(points,elements,colours,bodyPartMapping,saveGameLocation+"_bodySchematic_decoderI_yAxis.svg",
lightColor=whiteColorBar,darkColor=decoderIColorbar)
#print(coefficients_E_X)
# Out:
# Body Heatmap for decoder I x-axis
# Body Heatmap for decoder I y-axis

# %%
# Color code Plot for Decoder J
print("Body Heatmap for decoder J x-axis")
# Retrieve and reshape data 
coefficientsModel_x = modelJ_dict['Coeff'][0]
coefficientsModel_x_reshaped = coefficientsModel_x.reshape(2,3)

# Sum all coefficients across all rotations and positions for each rigid body and normalise
coefficientsModelSumDOF = np.sum(np.abs(coefficientsModel_x_reshaped),1)
coefficientsModelSumDOF = coefficientsModelSumDOF / sum(coefficientsModelSumDOF)

# Create a list with all rigid bodies in skeleton and set rigid bodies that don't have components to 0
coefficients_X = np.zeros((19))

coefficients_X[3:5] = coefficientsModelSumDOF[0:2]

# Normalise so the max value is 1
coefficients_X = coefficients_X/ max(coefficients_X)




# Set location and import body parts ( list of names of bodies that coefficients correspond to)


# Extract shape data from the svg file
elements,points,pathElements,bodyPartMapping = extractShapesFromSVG(location=location,parts=bodyParts)

# Set colours for each coefficient
colours = [get_color_hex(i,white,decoderJColor) for i in coefficients_X]


# Draw the object 
drawObject(points,elements,colours,bodyPartMapping,saveGameLocation+"_bodySchematic_decoderJ_xAxis.svg",
           lightColor=whiteColorBar,darkColor=decoderJColorbar)
#print(coefficients_E_X)


# For y axis
print("Body Heatmap for decoder J y-axis")
# Retrieve and reshape data 
coefficientsModel_y = modelJ_dict['Coeff'][1]
coefficientsModel_y_reshaped = coefficientsModel_y.reshape(2,3)

# Sum all coefficients across all rotations and positions for each rigid body and normalise
coefficientsModelSumDOF = np.sum(np.abs(coefficientsModel_y_reshaped),1)
coefficientsModelSumDOF = coefficientsModelSumDOF / sum(coefficientsModelSumDOF)

# Create a list with all rigid bodies in skeleton and set rigid bodies that don't have components to 0
coefficients_Y = np.zeros((19))

coefficients_Y[3:5] = coefficientsModelSumDOF[0:2]

# Normalise so the max value is 1
coefficients_Y = coefficients_Y/ max(coefficients_Y)


# Set location and import body parts ( list of names of bodies that coefficients correspond to)


# Extract shape data from the svg file
elements,points,pathElements,bodyPartMapping = extractShapesFromSVG(location=location,parts=bodyParts)

# Set colours for each coefficient
colours = [get_color_hex(i,white,decoderJColor) for i in coefficients_Y]


# Draw the object 
drawObject(points,elements,colours,bodyPartMapping,saveGameLocation+"_bodySchematic_decoderJ_yAxis.svg",
lightColor=whiteColorBar,darkColor=decoderJColorbar)
#print(coefficients_E_X)
# Out:
# Body Heatmap for decoder J x-axis
# Body Heatmap for decoder J y-axis
